# %%
import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Simple Linear Regression

# %%
x_data = torch.Tensor([1, 2, 3, 4, 5])
y_data = torch.Tensor([2, 4, 6, 8, 10])

x = x_data.view(5, 1)
y = y_data.view(5, 1)

print("x: ", x)
print("y: ", y)
# Out:
# x:  tensor([[1.],
#         [2.],
#         [3.],
#         [4.],
#         [5.]])
# y:  tensor([[ 2.],
#         [ 4.],
#         [ 6.],
#         [ 8.],
#         [10.]])

# %%
plt.scatter(x_data.numpy(), y_data.numpy())

# %%
learning_rate = 0.01

w = torch.rand(1, 1)

for step in range(20):
    pre = w * x
    cost = ((pre - y) ** 2).sum()
    grad = 2 * (pre - y).view(5).dot(x.view(5)) / len(x)
    w -= learning_rate * grad
    
    if step % 5 == 0:
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), pre.data.numpy(), 'r-')
        plt.title('step %d : cost=%.4f, w=%.4f, grad=%.4f' % (step, cost.item(), w.item(), grad.item()), fontdict={'size': 15})
        plt.show()

# %%
x_new = torch.Tensor([6])
y_new = w * x_new
y_new.item()
# Out:
# 11.947053909301758

# %% [markdown]
# # Define Model with nn.Linear, Optimizer

# %%
model = nn.Linear(1, 1, bias=True)
model.weight
# Out:
# Parameter containing:
# tensor([[0.5605]], requires_grad=True)

# %%
loss = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
for step in range(30):
    pre = model(x)
    cost = loss(pre, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if step % 5 == 0:
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), pre.data.numpy(), 'b-')
        plt.title('step %d, cost=%.4f, w=%.4f, grad=%4.f' 
                  % (step, cost.item() ,model.weight.item(), model.weight.grad.item()), fontdict={'size':15})
        plt.show()

# %%
x_new = torch.Tensor([6])
y_new = model(x_new)
y_new.item()
# Out:
# 12.17204761505127

# %%
test_x = torch.Tensor([10, 11, 12, 13, 14]).view(5, 1)
test_y = torch.Tensor([20, 22, 24, 26, 28]).view(5, 1)

for i in range(len(test_y)):
    output = model(test_x)
    correct += (test_y[i].item() == output[i].item())
    
print("predict: ", output)
print("real", test_y)
# Out:
# predict:  tensor([[20.4630],
#         [22.5358],
#         [24.6085],
#         [26.6813],
#         [28.7540]], grad_fn=<AddmmBackward>)
# real tensor([[20.],
#         [22.],
#         [24.],
#         [26.],
#         [28.]])
